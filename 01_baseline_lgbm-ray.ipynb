# %%
import ray

# %%
# 라이브러리 임포트
import os
import time
import json
from datetime import datetime
import numpy as np
import pandas as pd
from fbprophet import Prophet
import pickle
import copy

# %%
import seaborn as sns
from plotly import express as px

# %%
from darts.models import *
from darts.models.forecasting import gradient_boosted_model
import darts.utils.timeseries_generation as tg
from darts.utils.likelihood_models import GaussianLikelihood
from darts.datasets import EnergyDataset
from darts.utils.missing_values import fill_missing_values
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.timeseries import TimeSeries
import warnings

warnings.filterwarnings("ignore")
# Out:
# /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
# %%time
submit = json.load(open('./data/sample_submission/sample_submission.json', 'r', encoding='utf8')) 
df_dic = pickle.load(open('./mydata/df_dic.plk','rb'))
plc_lst = pickle.load(open('./mydata/plc_lst.plk','rb'))
fct_lst = ['pH', 'COD', 'SS', 'N', 'P', 'T']
# Out:
# CPU times: user 730 ms, sys: 165 ms, total: 895 ms
# Wall time: 896 ms

# %% [markdown]
# %%time
# ''' 스무딩 '''
# win_size = 3
#
#
# for plc in plc_lst:
#     df = df_dic[plc]
#     df = df.fillna(method='ffill')
#     df = df.fillna(method='bfill')
#
#     #print()
#
#     # 컬럼별 스무딩
#     for col in fct_lst:
#         series = df[col]
#         rolling = series.rolling(window=win_size)
#         rolling_median = rolling.median()
#         df_dic[plc][col] = rolling_median
#     df_dic[plc] = df_dic[plc].dropna()
#     df_dic[plc] = df_dic[plc].iloc[-1000:,:]

# %% [markdown]
# df = df_dic[plc_lst[0]]
# sns.lineplot(x = df.ds , y = df.pH)

# %% [markdown]
# df.pH.iloc[2800:]

# %%
# Prophet 예측을 위한 dataframe 포맷 제작
future = pd.DataFrame([str(x)[:10] for x in list(pd.date_range(start='2018-02-01', end='2019-12-31', inclusive="both"))], columns=['ds'])
future['y'] = np.nan
#future

# %%
''' test  '''
i = plc_lst[0]
j = fct_lst[0]

plc_df = df_dic[i]
fct_df = plc_df[['ds', j]]   # 날짜 - 피쳐1 조합임.
fct_df = fct_df.rename(columns={j:'y'}) # 피쳐1을 y로 바꾼다.
fct_df['ds'] = fct_df.ds.apply(lambda x : datetime.strptime(x , '%Y%m%d'))


model = Prophet()
model.fit(fct_df)
forecast = model.predict(future)
#forecast['ds'] = forecast['ds'].apply(lambda x : str(x).split(' ')[0].split('-')[0]+str(x).split(' ')[0].split('-')[1]+str(x).split(' ')[0].split('-')[2])
#forecast = forecast[['ds', 'yhat']]


# TimeSeris 로 변환 하기 
dfts = TimeSeries.from_dataframe(fct_df,  time_col = 'ds' , value_cols  = ['y'], fill_missing_dates=True)

# 
my_model = gradient_boosted_model.LightGBMModel(
lags=60,
output_chunk_length=1,
random_state= 2022)

my_model.fit(dfts)

pred_series = my_model.predict( n = 699 )
forecast = pred_series.pd_dataframe()

forecast['ds'] = forecast.index
forecast['ds'] = forecast['ds'].apply(lambda x : str(x).split(' ')[0].split('-')[0]+str(x).split(' ')[0].split('-')[1]+str(x).split(' ')[0].split('-')[2])
forecast.columns = ['yhat', 'ds']
forecast = forecast.reset_index(drop=True)

for index, k in enumerate(list(forecast['ds'])):
    submit[i][forecast.loc[index, 'ds']][j] = np.float(forecast[forecast['ds']==k]['yhat'])

# %% [markdown]
# ---
# # 예측 시작

# %%
@ray.remote
def pred_all_columns(plc_df,i,fct_lst,submit):
    
    res_list = []
    
    for j in fct_lst: # 피쳐 리스트
        fct_df = plc_df[['ds', j]]   # 날짜 - 피쳐1 조합임.
        
        fct_df = fct_df.rename(columns={j:'y'}) # 피쳐1을 y로 바꾼다.
        fct_df['ds'] = fct_df.ds.apply(lambda x : datetime.strptime(x , '%Y%m%d'))
        fct_df = fct_df.dropna()
        fct_df['y'] = pd.to_numeric(fct_df.y)
        
        df_align = pd.DataFrame([ x for x in list(pd.date_range( end = '2018-01-31', periods = len(fct_df), inclusive="both"))], columns=['ds'])
        df_align['y'] = fct_df.y.values
        
        # TimeSeris 로 변환 하기 
        dfts = TimeSeries.from_dataframe(df_align,  time_col = 'ds' , value_cols  = ['y'], fill_missing_dates=True  , freq='D')
        
        # 
        diff = datetime(2018,2,1) - fct_df.loc[0].ds
        if diff.days > 720:
            lag = 720
        else:
            lag = diff.days - 10

        my_model = gradient_boosted_model.LightGBMModel(
        lags=lag,
        output_chunk_length=1,
        random_state= 2022)
        
        my_model.fit(dfts)
        pred_series = my_model.predict( n = 699 )
        
        forecast = pred_series.pd_dataframe()
        forecast['ds'] = forecast.index
        forecast['ds'] = forecast['ds'].apply(lambda x : str(x).split(' ')[0].split('-')[0]+str(x).split(' ')[0].split('-')[1]+str(x).split(' ')[0].split('-')[2])
        forecast.columns = ['yhat', 'ds']
        forecast = forecast.reset_index(drop=True)
        
        for index, k in enumerate(list(forecast['ds'])):
            submit[i][forecast.loc[index, 'ds']][j] = float(forecast[forecast['ds']==k]['yhat'])
            
        res_list.append( (i,j,forecast) )
    return res_list

# %%
fct_lst_ray = ray.put(fct_lst)
submit_ray = ray.put(submit)

# %%
task_list = [ pred_all_columns.remote(df_dic[x], x ,fct_lst_ray, submit_ray) for x in plc_lst ]

# %%
# %%time
results = ray.get(task_list)
# Out:
# (pid=16515) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16515)   warn(f"Failed to load image Python extension: {e}")
# (pid=16521) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16521)   warn(f"Failed to load image Python extension: {e}")
# (pid=16508) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16508)   warn(f"Failed to load image Python extension: {e}")
# (pid=16525) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16525)   warn(f"Failed to load image Python extension: {e}")
# (pid=16507) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16507)   warn(f"Failed to load image Python extension: {e}")
# (pid=16528) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16528)   warn(f"Failed to load image Python extension: {e}")
# (pid=16519) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16519)   warn(f"Failed to load image Python extension: {e}")
# (pid=16509) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16509)   warn(f"Failed to load image Python extension: {e}")
# (pid=16506) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16506)   warn(f"Failed to load image Python extension: {e}")
# (pid=16492) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16492)   warn(f"Failed to load image Python extension: {e}")
# (pid=16512) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16512)   warn(f"Failed to load image Python extension: {e}")
# (pid=16516) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16516)   warn(f"Failed to load image Python extension: {e}")
# (pid=16517) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16517)   warn(f"Failed to load image Python extension: {e}")
# (pid=16524) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16524)   warn(f"Failed to load image Python extension: {e}")
# (pid=16523) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16523)   warn(f"Failed to load image Python extension: {e}")
# (pid=16497) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16497)   warn(f"Failed to load image Python extension: {e}")
# (pid=16486) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16486)   warn(f"Failed to load image Python extension: {e}")
# (pid=16535) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16535)   warn(f"Failed to load image Python extension: {e}")
# (pid=16484) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16484)   warn(f"Failed to load image Python extension: {e}")
# (pid=16491) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16491)   warn(f"Failed to load image Python extension: {e}")
# (pid=16505) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16505)   warn(f"Failed to load image Python extension: {e}")
# (pid=16501) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16501)   warn(f"Failed to load image Python extension: {e}")
# (pid=16510) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16510)   warn(f"Failed to load image Python extension: {e}")
# (pid=16518) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16518)   warn(f"Failed to load image Python extension: {e}")
# (pid=16530) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16530)   warn(f"Failed to load image Python extension: {e}")
# (pid=16482) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16482)   warn(f"Failed to load image Python extension: {e}")
# (pid=16494) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16494)   warn(f"Failed to load image Python extension: {e}")
# (pid=16511) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16511)   warn(f"Failed to load image Python extension: {e}")
# (pid=16499) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16499)   warn(f"Failed to load image Python extension: {e}")
# (pid=16526) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16526)   warn(f"Failed to load image Python extension: {e}")
# (pid=16527) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16527)   warn(f"Failed to load image Python extension: {e}")
# (pid=16493) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16493)   warn(f"Failed to load image Python extension: {e}")
# (pid=16483) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16483)   warn(f"Failed to load image Python extension: {e}")
# (pid=16487) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16487)   warn(f"Failed to load image Python extension: {e}")
# (pid=16522) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16522)   warn(f"Failed to load image Python extension: {e}")
# (pid=16488) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16488)   warn(f"Failed to load image Python extension: {e}")
# (pid=16513) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16513)   warn(f"Failed to load image Python extension: {e}")
# (pid=16498) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16498)   warn(f"Failed to load image Python extension: {e}")
# (pid=16490) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16490)   warn(f"Failed to load image Python extension: {e}")
# (pid=16496) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16496)   warn(f"Failed to load image Python extension: {e}")
# (pid=16495) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16495)   warn(f"Failed to load image Python extension: {e}")
# (pid=16514) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16514)   warn(f"Failed to load image Python extension: {e}")
# (pid=16529) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16529)   warn(f"Failed to load image Python extension: {e}")
# (pid=16503) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16503)   warn(f"Failed to load image Python extension: {e}")
# (pid=16489) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16489)   warn(f"Failed to load image Python extension: {e}")
# (pid=16485) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16485)   warn(f"Failed to load image Python extension: {e}")
# (pid=16500) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16500)   warn(f"Failed to load image Python extension: {e}")
# (pid=16504) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
# (pid=16504)   warn(f"Failed to load image Python extension: {e}")
# (pred_all_columns pid=16515) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16515)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16521) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16521)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16508) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16508)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16517) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16517)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16524) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16524)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16535) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16535)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16507) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16507)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16528) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16528)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16509) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16509)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16486) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16486)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16484) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16484)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16505) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16505)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16498) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16498)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16487) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16487)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16525) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16525)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16506) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16506)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16492) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16492)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16523) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16523)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16497) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16497)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16518) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16518)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16482) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16482)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16494) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16494)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16511) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16511)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16526) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16526)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16527) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16527)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16483) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16483)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16488) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16488)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16514) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16514)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16529) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16529)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16519) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16519)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16512) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16512)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16516) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16516)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16491) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16491)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16501) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16501)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16530) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16530)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16499) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16499)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16493) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16493)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16522) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16522)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16513) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16513)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16490) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16490)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16496) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16496)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16489) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16489)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16500) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16500)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16510) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16510)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16503) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16503)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16485) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16485)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16504) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16504)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16495) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16495)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16482) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16482)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16496) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16496)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16526) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16526)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16496) [2022-06-14 10:18:43,801] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16496) [2022-06-14 10:18:43,801] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16496) [2022-06-14 10:18:43,801] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16496) [2022-06-14 10:18:43,801] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16496) [2022-06-14 10:18:43,801] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16496) 2022-06-14 10:18:43 main_logger ERROR: ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16517) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16517)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16526) [2022-06-14 10:18:43,844] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16526) [2022-06-14 10:18:43,844] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16526) [2022-06-14 10:18:43,844] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16526) [2022-06-14 10:18:43,844] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16526) [2022-06-14 10:18:43,844] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16526) 2022-06-14 10:18:43 main_logger ERROR: ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16498) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16498)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16521) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16521)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16535) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16535)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16513) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16513)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16513) [2022-06-14 10:18:44,103] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16513) [2022-06-14 10:18:44,103] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16513) [2022-06-14 10:18:44,103] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16513) [2022-06-14 10:18:44,103] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16513) [2022-06-14 10:18:44,103] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16513) 2022-06-14 10:18:44 main_logger ERROR: ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# ---------------------------------------------------------------------------
# RayTaskError(ValueError)                  Traceback (most recent call last)
# <timed exec> in <module>
#
# /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/ray/worker.py in get(object_refs, timeout)
#    1829                     worker.core_worker.dump_object_store_memory_usage()
#    1830                 if isinstance(value, RayTaskError):
# -> 1831                     raise value.as_instanceof_cause()
#    1832                 else:
#    1833                     raise value
#
# RayTaskError(ValueError): ray::pred_all_columns() (pid=16496, ip=172.17.10.13)
#   File "/tmp/ipykernel_47934/1232142960.py", line 33, in pred_all_columns
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/models/forecasting/gradient_boosted_model.py", line 162, in fit
#     super().fit(
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py", line 427, in fit
#     self._fit_model(
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py", line 321, in _fit_model
#     training_samples, training_labels = self._create_lagged_data(
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py", line 292, in _create_lagged_data
#     raise_if(
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/logging.py", line 110, in raise_if
#     raise_if_not(not condition, message, logger)
#   File "/ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/logging.py", line 84, in raise_if_not
#     raise ValueError(message)
# ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16505) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16505)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16518) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16518)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16487) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16487)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16528) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16528)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16506) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16506)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16524) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16524)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16510) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16510)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16530) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16530)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16494) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16494)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16511) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16511)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16499) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16499)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16522) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16522)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16529) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16529)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16515) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16515)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16497) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16497)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16510) [2022-06-14 10:18:44,432] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16510) [2022-06-14 10:18:44,432] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16510) [2022-06-14 10:18:44,432] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16510) [2022-06-14 10:18:44,432] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# (pred_all_columns pid=16510) [2022-06-14 10:18:44,432] ERROR | main_logger | ValueError: Unable to build any training samples of the target series and the corresponding covariate series; There is no time step for which all required lags are available and are not NaN values.
# ...
# (pred_all_columns pid=16507)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16511) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16511)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16527) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16527)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16495) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16495)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16487) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16487)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16509) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16509)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16524) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16524)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16517) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16517)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16514) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16514)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16504) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16504)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16525) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16525)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16512) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16512)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16491) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16491)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16535) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16535)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16484) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16484)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16505) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16505)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16530) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16530)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16492) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16492)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16529) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16529)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16497) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16497)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16510) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16510)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16528) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16528)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16490) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16490)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16488) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16488)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16523) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16523)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16498) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16498)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16515) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16515)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16483) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16483)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16519) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16519)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16482) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16482)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16518) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16518)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16500) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16500)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16527) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16527)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16486) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16486)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16489) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16489)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16508) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16508)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16522) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16522)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16506) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16506)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16526) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16526)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16494) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16494)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16516) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16516)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16521) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16521)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16499) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16499)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16501) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16501)   if isinstance(time_idx, pd.Int64Index) and not isinstance(
# (pred_all_columns pid=16503) /ssd/jaewoo/anaconda3/envs/ts/lib/python3.9/site-packages/darts/timeseries.py:3305: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# (pred_all_columns pid=16503)   if isinstance(time_idx, pd.Int64Index) and not isinstance(

# %%
for item in results:
    for x in item:
        i = x[0]
        j = x[1]
        forecast = x[2]
        for index, k in enumerate(list(forecast['ds'])):
            submit[i][forecast.loc[index, 'ds']][j] = np.float(forecast[forecast['ds']==k]['yhat'])
# Out:
# /tmp/ipykernel_10600/3712719606.py:7: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   submit[i][forecast.loc[index, 'ds']][j] = np.float(forecast[forecast['ds']==k]['yhat'])

# %%
# 추론 파일 저장
with open('./sub/baseline_median3.json', 'w', encoding='utf8') as f:
    json.dump(submit, f, ensure_ascii=False)
